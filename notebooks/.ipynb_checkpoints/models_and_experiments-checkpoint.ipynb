# %%
import os

if os.path.basename(os.getcwd()) != "Amsterdam-House-Price-Prediction": os.chdir("..")

# %% [markdown]
# # 🏡 Сравнение моделей для предсказания цен на жильё в Амстердаме
#
# Этот ноутбук:
# - Загружает **очищенные данные**
# - Применяет несколько моделей регрессии
# - Сравнивает их по метрикам
# - Сохраняет обученные модели

# %% [markdown]
# 🔹 Импорты и настройки

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from src.preprocessing import load_cleaned_data
from src.train import scale_features, train_test_split_data
from src.evaluate import evaluate_model
from src.utils import save_model_named

sns.set(style="whitegrid")

# %% [markdown]
# 🔹 Загрузка очищенных данных

# %%
df = load_cleaned_data(path="data/cleaned.csv")
df.head(2)
# Out:
#       price  area  rooms  price_per_sqm  area_per_room  lat_bin  lon_bin  \
# 0  685000.0  64.0    3.0   10703.125000      21.333333    52.36     4.91
# 1  475000.0  60.0    3.0    7916.666667      20.000000    52.35     4.85
#
#    distance_to_center_km  zip_prefix
# 0               1.297179        1091
# 1               4.221765        1059

# %% [markdown]
# 🔹 Разделение на признаки и целевую переменную

# %%
FEATURES = ["area", "rooms", "price_per_sqm", "area_per_room", "lat_bin", "lon_bin", "distance_to_center_km", "zip_prefix"]
TARGET = "price"

X = df[FEATURES]
y = df[TARGET]

# %% [markdown]
# 🔹 Масштабирование и сплит

# %%
X_scaled = scale_features(X.copy(), FEATURES)
X_train, X_test, y_train, y_test = train_test_split_data(X_scaled, y)

# %% [markdown]
# 🔹 Объявление моделей

# %%
models = {
    "LinearRegression": LinearRegression(),
    "Ridge(alpha=1.0)": Ridge(alpha=1.0),
    "DecisionTree(depth=5)": DecisionTreeRegressor(max_depth=5),
    "RandomForest(n=50)": RandomForestRegressor(n_estimators=50, random_state=42)
}

# %% [markdown]
# 🔹 Обучение, предсказание, оценка и сохранение

# %%
results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    metrics = evaluate_model(y_test, y_pred)
    metrics["Model"] = name
    results.append(metrics)

    safe_name = name.lower().replace("(", "_").replace(")", "").replace("=", "_").replace(" ", "").replace(",", "")
    save_model_named(model, safe_name)
# Out:
# ✅ Модель сохранена: models\linearregression.joblib
# ✅ Модель сохранена: models\ridge_alpha_1.0.joblib
# ✅ Модель сохранена: models\decisiontree_depth_5.joblib
# ✅ Модель сохранена: models\randomforest_n_50.joblib

# %% [markdown]
# 🔹 Отображение результатов

# %%
df_results = pd.DataFrame(results).set_index("Model")
df_results.style.background_gradient(cmap="Blues").format("{:.2f}")
# Out:
# <style type="text/css">
# #T_7a3c7_row0_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_7a3c7_row0_col1, #T_7a3c7_row0_col2, #T_7a3c7_row2_col0, #T_7a3c7_row3_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7a3c7_row0_col3, #T_7a3c7_row1_col3, #T_7a3c7_row3_col0, #T_7a3c7_row3_col1, #T_7a3c7_row3_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7a3c7_row1_col0 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_7a3c7_row1_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_7a3c7_row1_col2 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_7a3c7_row2_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_7a3c7_row2_col2 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_7a3c7_row2_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# </style>
# <table id="T_7a3c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a3c7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7a3c7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7a3c7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7a3c7_level0_col3" class="col_heading level0 col3" >R2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a3c7_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_7a3c7_row0_col0" class="data row0 col0" >59425.23</td>
#       <td id="T_7a3c7_row0_col1" class="data row0 col1" >14154977094.49</td>
#       <td id="T_7a3c7_row0_col2" class="data row0 col2" >118974.69</td>
#       <td id="T_7a3c7_row0_col3" class="data row0 col3" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_7a3c7_level0_row1" class="row_heading level0 row1" >Ridge(alpha=1.0)</th>
#       <td id="T_7a3c7_row1_col0" class="data row1 col0" >59312.28</td>
#       <td id="T_7a3c7_row1_col1" class="data row1 col1" >14078205703.07</td>
#       <td id="T_7a3c7_row1_col2" class="data row1 col2" >118651.61</td>
#       <td id="T_7a3c7_row1_col3" class="data row1 col3" >0.89</td>
#     </tr>
#     <tr>
#       <th id="T_7a3c7_level0_row2" class="row_heading level0 row2" >DecisionTree(depth=5)</th>
#       <td id="T_7a3c7_row2_col0" class="data row2 col0" >69863.55</td>
#       <td id="T_7a3c7_row2_col1" class="data row2 col1" >12131858678.39</td>
#       <td id="T_7a3c7_row2_col2" class="data row2 col2" >110144.72</td>
#       <td id="T_7a3c7_row2_col3" class="data row2 col3" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_7a3c7_level0_row3" class="row_heading level0 row3" >RandomForest(n=50)</th>
#       <td id="T_7a3c7_row3_col0" class="data row3 col0" >24285.04</td>
#       <td id="T_7a3c7_row3_col1" class="data row3 col1" >4954542921.95</td>
#       <td id="T_7a3c7_row3_col2" class="data row3 col2" >70388.51</td>
#       <td id="T_7a3c7_row3_col3" class="data row3 col3" >0.96</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# 🔹 Визуализация: реальное vs предсказанное и важность признаков

# %%
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # 🧮 Подсчёт важностей признаков
    if hasattr(model, 'feature_importances_'):
        importances = model.feature_importances_
    elif hasattr(model, 'coef_'):
        importances = np.abs(model.coef_)
    else:
        importances = None

    # 📊 Два графика рядом
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # График 1: Реальные vs Предсказанные значения
    sns.scatterplot(ax=axes[0], x=y_test, y=y_pred, alpha=0.7)
    axes[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
    axes[0].set_title(f"{name} | Реальное vs Предсказанное")
    axes[0].set_xlabel("Реальные значения")
    axes[0].set_ylabel("Предсказанные значения")

    # График 2: Важность признаков
    if importances is not None:
        sns.barplot(ax=axes[1], x=importances, y=X_train.columns, orient='h')
        axes[1].set_title(f"{name} | Важность признаков")
        axes[1].set_xlabel("Importance")
    else:
        axes[1].set_visible(False)

    plt.tight_layout()
    plt.show()
